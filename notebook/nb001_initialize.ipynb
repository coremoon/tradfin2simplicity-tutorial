# %%
import pyhalsimplicity
import pysimplicityhl
import os
basedir = os.getcwd()

def wrap_quotes(filename):
    return f"'{filename}'"

# %%
print(dir(pyhalsimplicity))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'do_something', 'get_logs', 'pyhalsimplicity', 'run_cli_command', 'setup_logger']

# %%
print(dir(pysimplicityhl))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'pysimplicityhl', 'run_from_python']

# %%
simple_file = f"{basedir}/simple.simf"
print(simple_file)
# print(os.path.exists(simple_file))
pysimplicityhl.run_from_python(f"'{simple_file}'")
# Out:
# D:\work\simplicity\tradfin2simplicity-tutorial\notebook/simple.simf
# '{"status":"success","program":"JA=="}'
